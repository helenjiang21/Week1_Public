# %% [markdown]
# # Pandas Problem Set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
url = "https://raw.githubusercontent.com/BeaverWorksMedlytics2020/Data_Public/master/NotebookExampleData/Week1/diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

# %% [markdown]
# Read in csv above to a pandas dataframe

# %%
# your code here
data = pd.read_csv(url, names=names)

# %% [markdown]
# Print out the age and class of the 100th patient

# %%
# your code here
data.loc[99, "age":"class"]
# Out:
# age      31.0
# class     1.0
# Name: 99, dtype: float64

# %% [markdown]
# Write code to figure out how many people are classified as not having diabetes, class is 0

# %%
# your code here
data[data["class"] ==0]
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 1       1    85    66    29     0  26.6  0.351   31      0
# 3       1    89    66    23    94  28.1  0.167   21      0
# 5       5   116    74     0     0  25.6  0.201   30      0
# 7      10   115     0     0     0  35.3  0.134   29      0
# 10      4   110    92     0     0  37.6  0.191   30      0
# 12     10   139    80     0     0  27.1  1.441   57      0
# 18      1   103    30    38    83  43.3  0.183   33      0
# 20      3   126    88    41   235  39.3  0.704   27      0
# 21      8    99    84     0     0  35.4  0.388   50      0
# 27      1    97    66    15   140  23.2  0.487   22      0
# 28     13   145    82    19   110  22.2  0.245   57      0
# 29      5   117    92     0     0  34.1  0.337   38      0
# 30      5   109    75    26     0  36.0  0.546   60      0
# 32      3    88    58    11    54  24.8  0.267   22      0
# 33      6    92    92     0     0  19.9  0.188   28      0
# ...

# %% [markdown]
# Write code to figure out how many people are classified as having diabetes, class is 1

# %%
# your code here
diabetes = data[data["class"] ==1]
diabetes.count()
# Out:
# preg     268
# plas     268
# pres     268
# skin     268
# test     268
# mass     268
# pedi     268
# age      268
# class    268
# dtype: int64

# %% [markdown]
# What percent of people have diabetes in the study

# %%
# your code here
diabetes.count()/data.count()
# Out:
# preg     0.348958
# plas     0.348958
# pres     0.348958
# skin     0.348958
# test     0.348958
# mass     0.348958
# pedi     0.348958
# age      0.348958
# class    0.348958
# dtype: float64

# %% [markdown]
# Print out the pressure and class (no other columns) for the first 5 people (hint: this was not shown in our tutorial google how to select multiple columns with loc)
#
# Being able to effectively google is a very important coding tool ¯\\\_(ツ)_/¯

# %%
# your code here
data.loc[:, ("pres", "class")]
# Out:
#      pres  class
# 0      72      1
# 1      66      0
# 2      64      1
# 3      66      0
# 4      40      1
# 5      74      0
# 6      50      1
# 7       0      0
# 8      70      1
# 9      96      1
# 10     92      0
# 11     74      1
# 12     80      0
# 13     60      1
# 14     72      1
# 15      0      1
# 16     84      1
# 17     74      1
# 18     30      0
# 19     70      1
# 20     88      0
# 21     84      0
# 22     90      1
# 23     80      1
# 24     94      1
# 25     70      1
# 26     76      1
# 27     66      0
# 28     82      0
# 29     92      0
# ..    ...    ...
# 738    60      0
# 739    74      1
# 740    80      1
# 741    44      0
# 742    58      0
# 743    94      1
# 744    88      0
# 745    84      0
# 746    94      1
# 747    74      0
# 748    70      1
# 749    62      1
# 750    70      1
# 751    78      0
# 752    62      0
# 753    88      1
# 754    78      1
# 755    88      1
# 756    90      0
# 757    72      1
# ...

# %% [markdown]
# Run the cell below, it will print out the correlation among the columns

# %%
data.corr()
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %% [markdown]
# What column has the highest correlation with class? Find the mean() value of that column

# %%
# your code here
mean = np.mean(data.loc[:, "plas"])
mean
# Out:
# 120.89453125

# %% [markdown]
# Create a new dataframe with only people that are above the mean found above

# %%
# your code here
data[data["plas"]>mean]
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 2       8   183    64     0     0  23.3  0.672   32      1
# 4       0   137    40    35   168  43.1  2.288   33      1
# 8       2   197    70    45   543  30.5  0.158   53      1
# 9       8   125    96     0     0   0.0  0.232   54      1
# 11     10   168    74     0     0  38.0  0.537   34      1
# 12     10   139    80     0     0  27.1  1.441   57      0
# 13      1   189    60    23   846  30.1  0.398   59      1
# 14      5   166    72    19   175  25.8  0.587   51      1
# 20      3   126    88    41   235  39.3  0.704   27      0
# 22      7   196    90     0     0  39.8  0.451   41      1
# 24     11   143    94    33   146  36.6  0.254   51      1
# 25     10   125    70    26   115  31.1  0.205   41      1
# 26      7   147    76     0     0  39.4  0.257   43      1
# 28     13   145    82    19   110  22.2  0.245   57      0
# ...

# %% [markdown]
# Create a new dataframe that only includes people who are above the average value for each column in the dataset (except 'class'). In other words, find the average value for each column, and then find which users have values above all of these average column values

# %%
# write code here
mean_table = data.mean()
mean_table = mean_table[:-1]
mean_dict = mean_table.to_dict()
filtered = data[(data['preg'] > mean_dict.get("preg")) & (data['plas'] > mean_dict.get("plas")) & (data['pres'] > mean_dict.get("pres"))
               & (data['skin'] > mean_dict.get("skin")) & (data['test'] > mean_dict.get("test")) 
               & (data['mass'] > mean_dict.get("mass")) & (data['pedi'] > mean_dict.get("pedi"))
               & (data['age'] > mean_dict.get("age"))]
filtered
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 43      9   171   110    24   240  45.4  0.721   54      1
# 152     9   156    86    28   155  34.3  1.189   42      1
# 159    17   163    72    41   114  40.9  0.817   47      1
# 175     8   179    72    42   130  32.7  0.719   36      1
# 206     8   196    76    29   280  37.5  0.605   57      1
# 215    12   151    70    40   271  41.8  0.742   38      1
# 236     7   181    84    21   192  35.9  0.586   51      1
# 259    11   155    76    28   150  33.3  1.353   51      1
# 286     5   155    84    44   545  38.7  0.619   34      0
# 375    12   140    82    43   325  39.2  0.528   58      1
# 424     8   151    78    32   210  42.9  0.516   36      1
# 458    10   148    84    48   237  37.6  1.001   51      1
# 546     5   187    76    27   207  43.6  1.034   53      1
# 594     6   123    72    45   230  33.6  0.733   34      0
# 603     7   150    78    29   126  35.2  0.692   54      1
# ...

# %%
means = mean_dict
for i in names:
    if i!='class':
        means[i] = data[i].mean()
ok = np.ndarray((data.shape[0]), dtype=bool)
ok.fill(True)

for i in names:
    if i!='class':
        ok = ok & (data[i]>means[i])

data3 = data[ok]
data3
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 43      9   171   110    24   240  45.4  0.721   54      1
# 152     9   156    86    28   155  34.3  1.189   42      1
# 159    17   163    72    41   114  40.9  0.817   47      1
# 175     8   179    72    42   130  32.7  0.719   36      1
# 206     8   196    76    29   280  37.5  0.605   57      1
# 215    12   151    70    40   271  41.8  0.742   38      1
# 236     7   181    84    21   192  35.9  0.586   51      1
# 259    11   155    76    28   150  33.3  1.353   51      1
# 286     5   155    84    44   545  38.7  0.619   34      0
# 375    12   140    82    43   325  39.2  0.528   58      1
# 424     8   151    78    32   210  42.9  0.516   36      1
# 458    10   148    84    48   237  37.6  1.001   51      1
# 546     5   187    76    27   207  43.6  1.034   53      1
# 594     6   123    72    45   230  33.6  0.733   34      0
# 603     7   150    78    29   126  35.2  0.692   54      1
# ...

# %%
df[np.sum(df.iloc[:, :-1] > np.array(np.mean(df))[:-1], axis=1) == 8]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-38c77de48fd2> in <module>
# ----> 1 df[np.sum(df.iloc[:, :-1] > np.array(np.mean(df))[:-1], axis=1) == 8]
#
# NameError: name 'df' is not defined

# %% [markdown]
# Ignoring the index (resetting the index to 0), sort the values based on "skin", "test", and "pedi" values in ascending order. Please write this in one line.

# %%
# write code here 
data.sort_values(by = ["skin", "test", "pedi"], ascending = True)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 268     0   102    52     0     0  25.1  0.078   21      0
# 180     6    87    80     0     0  23.2  0.084   32      0
# 598     1   173    74     0     0  36.8  0.088   38      1
# 81      2    74     0     0     0   0.0  0.102   22      0
# 430     2    99     0     0     0  22.2  0.108   23      0
# 560     6   125    76     0     0  33.8  0.121   54      1
# 714     3   102    74     0     0  29.5  0.121   32      0
# 474     4   114    64     0     0  28.9  0.126   24      0
# 678     3   121    52     0     0  36.0  0.127   25      1
# 319     6   194    78     0     0  23.5  0.129   59      1
# 586     8   143    66     0     0  34.9  0.129   41      1
# 7      10   115     0     0     0  35.3  0.134   29      0
# 404     5   168    64     0     0  32.9  0.135   41      1
# 154     8   188    78     0     0  47.9  0.137   43      1
# 333    12   106    80     0     0  23.6  0.137   44      0
# ...

# %% [markdown]
# Notice that there are some repeats in values (like in the age and the preg column).

# %% [markdown]
# Now Let's find the 4 largest values for "age" and "mass". Reference the pandas documentation (https://pandas.pydata.org/docs/) if you are stuck!

# %%
# write code here
data.nlargest(4, "age")
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 459     9   134    74    33    60  25.9  0.460   81      0
# 453     2   119     0     0     0  19.6  0.832   72      0
# 666     4   145    82    18     0  32.5  0.235   70      1
# 123     5   132    80     0     0  26.8  0.186   69      0

# %%
data.nlargest(4, "mass")
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 177     0   129   110    46   130  67.1  0.319   26      1
# 445     0   180    78    63    14  59.4  2.420   25      1
# 673     3   123   100    35   240  57.3  0.880   22      0
# 125     1    88    30    42    99  55.0  0.496   26      1

# %% [markdown]
# Now find the smallest 4 values for "plas" and "preg" in reverse order (largest to smallest). Please refer to the API documentation if you are stuck-- https://pandas.pydata.org/pandas-docs/stable/reference/index.html

# %%
#write code here
plas = data.sort_values(by = "plas", ascending = False)
plas.head(4)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 661     1   199    76    43     0  42.9  1.394   22      1
# 561     0   198    66    32   274  41.3  0.502   28      1
# 228     4   197    70    39   744  36.7  2.329   31      0
# 8       2   197    70    45   543  30.5  0.158   53      1

# %%
preg = data.sort_values(by = "preg", ascending = False)
preg.head(4)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 159    17   163    72    41   114  40.9  0.817   47      1
# 88     15   136    70    32   110  37.1  0.153   43      1
# 298    14   100    78    25   184  36.6  0.412   46      1
# 455    14   175    62    30     0  33.6  0.212   38      1
